# %%
import pandas as pd
import plotly.express as px

car_data = pd.read_csv('/Users/gerardoparada/Documents/TECH/BOOT/vehicles_env/vehicles.csv')
print(car_data.columns)

columns_to_drop = ['url', 'company', 'price_financed', 'is_professional', 'dealer']
car_data = car_data.drop(columns=columns_to_drop)
print(car_data.columns)

car_data.to_csv('/Users/gerardoparada/Documents/TECH/BOOT/vehicles_env/cleaned_vehicles.csv', index=False)

fig = px.histogram(car_data, x="year")
fig.show()

fig = px.scatter(car_data, x="year", y="price")
fig.show()
# Out:
# Index(['url', 'company', 'make', 'model', 'version', 'price', 'price_financed',
#        'fuel', 'year', 'kms', 'power', 'doors', 'shift', 'color', 'photos',
#        'is_professional', 'dealer', 'province', 'country', 'publish_date',
#        'insert_date'],
#       dtype='object')
# Index(['make', 'model', 'version', 'price', 'fuel', 'year', 'kms', 'power',
#        'doors', 'shift', 'color', 'photos', 'province', 'country',
#        'publish_date', 'insert_date'],
#       dtype='object')
